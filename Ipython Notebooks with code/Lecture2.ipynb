# %% [markdown]
# # Script for Lecture 2
# Current warehouse robots like Kiva do not learn over time. They are programmed to behave in a certain manner. We consider the scenario of making the robots even smarter by allowing them to stack objects into appropriate locations for efficient retrieval.
#
# How would go about designing such system? The key task to be executed is: given an input object, can the robot tell if it is a chair or a table. There are some obvious engineering issues here. How does the robot take the object as input? How does it communicate (tell) its decision? We will ignore those for this course and assume that the robot’s decision making module is a software which takes a digital representation of the object as input and outputs a binary signal, 0 for table and 1 for chair.
# We still need to figure out what the digital representation is going to be. Here is the first key difference between humans and machines, in the context of learning. Humans automatically perceive a sensory input. Machines see a machine translated input. Let us use the following examples to understand the difference.

# %%
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
# this is how our brain perceives two images
fig, axes = plt.subplots(1, 2, figsize=(12, 4),dpi=196)
img1 = plt.imread('../data/table1.JPG')
img2 = plt.imread('../data/table2.JPG')
axes[0].imshow(img1)
axes[1].imshow(img2)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-3-a81aa4e6d915> in <module>()
#       1 # this is how our brain perceives two images
#       2 fig, axes = plt.subplots(1, 2, figsize=(12, 4),dpi=196)
# ----> 3 img1 = plt.imread('../data/table1.JPG')
#       4 img2 = plt.imread('../data/table2.JPG')
#       5 axes[0].imshow(img1)
#
# /usr/local/lib/python2.7/site-packages/matplotlib/pyplot.pyc in imread(*args, **kwargs)
#    2213 @docstring.copy_dedent(_imread)
#    2214 def imread(*args, **kwargs):
# -> 2215     return _imread(*args, **kwargs)
#    2216
#    2217
#
# /usr/local/lib/python2.7/site-packages/matplotlib/image.pyc in imread(fname, format)
#    1252
#    1253     if ext not in handlers:
# -> 1254         im = pilread(fname)
#    1255         if im is None:
#    1256             raise ValueError('Only know how to handle extensions: %s; '
#
# /usr/local/lib/python2.7/site-packages/matplotlib/image.pyc in pilread(fname)
#    1231         if cbook.is_string_like(fname):
#    1232             # force close the file after reading the image
# -> 1233             with open(fname, "rb") as fh:
#    1234                 image = Image.open(fh)
#    1235                 return pil_to_array(image)
#
# IOError: [Errno 2] No such file or directory: '../data/table1.JPG'

# %%
# this is what the computer will see
x = np.linspace(0, 49, 50)
y = np.linspace(0, 49, 50)

fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111)
ax.set_xlim((0,50))
ax.set_ylim((0,50))

for i in x:
    for j in y:
        ax.annotate(str(img1[j,i]), xy=(i,j))
        
#flip the axis
ax.set_ylim(ax.get_ylim()[::-1])
# Out:
# (50.0, 0.0)
